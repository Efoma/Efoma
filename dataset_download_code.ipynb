# %% [markdown]
# <a href="https://colab.research.google.com/github/Efoma/Efoma/blob/main/dataset_download_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def read_modis(hdf_path):
    # Implementation of read_modis function
    pass

# %%
pip install pymodis
# Out:
# Requirement already satisfied: pymodis in /usr/local/lib/python3.10/dist-packages (2.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pymodis) (1.25.2)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from pymodis) (0.18.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pymodis) (2.31.0)
# Requirement already satisfied: GDAL in /usr/local/lib/python3.10/dist-packages (from pymodis) (3.6.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pymodis) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pymodis) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pymodis) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pymodis) (2024.7.4)

# %%
pip install pymp-pypi
# Out:
# Collecting pymp-pypi
#   Downloading pymp-pypi-0.5.0.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pymp-pypi
#   Building wheel for pymp-pypi (setup.py) ... done
#   Created wheel for pymp-pypi: filename=pymp_pypi-0.5.0-py3-none-any.whl size=10318 sha256=c46af3e3f7cbd2f91eafc9174fd6f958e42ac9357d3d6bdf1f34b3ab3e9670f4
#   Stored in directory: /root/.cache/pip/wheels/5e/db/4b/4c02f5b91b1abcde14433d1b336ac00a09761383e7bb1013cf
# Successfully built pymp-pypi
# Installing collected packages: pymp-pypi
# Successfully installed pymp-pypi-0.5.0

# %%
import pymodis
print(pymodis.__version__)
# Out:
# 2.4.1

# %%
import os
from pymodis import downmodis
import numpy as np
import pymp
import time
from argparse import ArgumentParser
import shutil
import multiprocessing as mp
import calendar

# %%
def calculate_dates_daily(year, month):
    """
    This function calculate the dates of the days of the given month in the given year. Those dates will be used
    later to download the daily images from both the MODIS products
    """
    startdates = ["{}-{}-01".format(str(year),str(month).zfill(2))]
    enddates = []
    for day in range(2, total_days+1):
        enddates.append("{}-{}-{}".format(str(year),str(month).zfill(2),str(day).zfill(2)))
        startdates.append("{}-{}-{}".format(str(year),str(month).zfill(2),str(day).zfill(2)))

    if month != 12:
        enddates.append("{}-{}-01".format(str(year),str(month+1).zfill(2)))
    else:
        enddates.append("{}-01-01".format(str(year+1)))

    return startdates, enddates

# %%
def MODIS_Downloader(startdate, enddate, year, product, num_threads, tiles, user="efoma", password="Naijament@75"):
    sensor        = product.split(".")[0]
    hdfs_path     = 'MODIS/MOD_{}_{}/hdfs_files'.format(year,sensor)

    start_time = time.time()
    print("Start to download {} From {} to {}".format(hdfs_path, startdate,enddate))

    try:
        modisDown = downmodis.downModis(user=user,password=password,product=product,destinationFolder=hdfs_path, tiles=tiles, today=startdate, enddate=enddate)
        modisDown.connect()
        modisDown.downloadsAllDay()
    except:
        print("Download Error {} From {} to {}".format(hdfs_path, startdate,enddate))
    print("Finish download {} From {} to {}, time cost: {:.4f}".format(hdfs_path, startdate,enddate,time.time()-start_time))

# %%
def MODIS_Downloader_DAILY(startdate, enddate, year, product, tiles, user="efoma", password="Naijament@75"):
    sensor = product.split(".")[0]
    hdfs_path = 'MODIS/MOD_{}_{}/hdfs_files'.format(year,sensor)

    start_time = time.time()
    print("Start to download {} From {} to {}".format(hdfs_path, startdate,enddate))

    try:
        modisDown = downmodis.downModis(user=user,password=password,product=product,destinationFolder=hdfs_path, tiles=tiles, today=startdate, enddate=enddate)
        modisDown.connect()
        modisDown.downloadsAllDay()
    except:
        print("Download Error {} From {} to {}".format(hdfs_path, startdate,enddate))

    print("Finish download {} From {} to {}, time cost: {:.4f}".format(hdfs_path, startdate,enddate,time.time()-start_time))

# %%
def MODIS_Data_Preprocessing(year, product, num_threads, delete_files=False):
    """
    This function processes the hdf files in the given year and saves the NDVI and LST images in tiff format.
    If delete_files argument is set to True, the processed hdf files are deleted after.
    """
    sensor        = product.split(".")[0]
    root_dir      = 'MODIS/MOD_{}_{}'.format(year,sensor)
    hdfs_path     = os.path.join(root_dir, 'hdfs_files')
    tifs_1km_path = os.path.join(root_dir, 'tifs_files/1km')
    tifs_250m_path = os.path.join(root_dir, 'tifs_files/250m')

    os.makedirs(hdfs_path,exist_ok=1)

    # Create the save folders based on the processed sensor
    if sensor == 'MOD11A1':
        os.makedirs(tifs_1km_path,exist_ok=1)
    elif sensor == 'MOD13A2':
        os.makedirs(tifs_1km_path,exist_ok=1)
    elif sensor == "MOD13Q1":
        os.makedirs(tifs_250m_path,exist_ok=1)

    # Load the ndvi hdf files
    ndvi_folder = 'MODIS/MOD_{}_MOD09GQ'.format(year)
    ndvi_save_path = os.path.join(ndvi_folder, 'tifs_files/250m')
    ndvi_dir     = os.path.join(ndvi_folder, 'hdfs_files')
    os.makedirs(ndvi_save_path,exist_ok=1)

    list_ndvi =  os.listdir(ndvi_dir)
    indexes_to_delete=[]
    for index in range(len(list_ndvi)):
        if not list_ndvi[index].endswith('hdf'):
            indexes_to_delete.append(index)
    for j in sorted(indexes_to_delete,reverse=True):
        del list_ndvi[j]
    list_ndvi.sort()

    # Start processing file by file
    print("start to processing {}".format(hdfs_path))
    hdfs = os.listdir(hdfs_path)
    hdfs.sort()
    start_time = time.time()
    # Core images with multi-core
    with pymp.Parallel(num_threads) as p:
        for index in p.range(0, len(hdfs)):

            # Process only hdf files
            hdf = hdfs[index]
            if not hdf.endswith('hdf'): continue
            hdf_path = os.path.join(hdfs_path,hdf)

            # Process LST and NDVI images
            if sensor=='MOD11A1':
                process_hdf(hdf_path, hdf,tifs_1km_path,ndvi_save_path,list_ndvi,ndvi_dir, 64, (64,64))

    # Delete files ar the end
    if delete_files:
        shutil.rmtree(ndvi_dir, ignore_errors=False, onerror=None)
        shutil.rmtree(hdfs_path, ignore_errors=False, onerror=None)

    print("Using {:.4f}s to process product = {}".format(time.time()-start_time, product))

# %%
def process_hdf(hdf_path, hdf_name, save_dir,ndvi_save_path,list_ndvi,ndvi_dir,step=64,size=(64,64)):
    """
    INPUT:
    hdf_path = input LST image path to be processed | or hdf file path ("/a/b/c.hdf")
    hdf_name = name of the hdf file
    save_dir = directory for saving cropped images
    ndvi_save_path : Path to save the ndvi images
    ndvi_dir : path of the ndvi hdf files
    list_ndvi : List of the ndvi files
    step, size: parameters of "sliding_window()"
    OUTPUT: LST and NDVI images cropped from the hdf files, saved to save_dir in tiff format
    """
    if not hdf_path.endswith('hdf'):
        print("Not hdf file Sorry!")
        return
    # Open the LST hdf
    read_val = read_modis(hdf_path)
    # Ignore the file in the processing it there are errors when opening it
    if read_val is None:
        print("Cannot handle this MODIS file: ", hdf_path, ". Please check it again")
        return

    img_day, img_night, cols, rows, projection, geotransform = read_val

    img_days = []
    img_nights = []
    img_cropped_names = []
    ndvis = []
    ndvi_names = []
    ndvi_geotransforms = []
    geotransform2s = []
    cols2, rows2 = size

    if img_day is None or img_night is None:
        print("Cannot handle this MODIS file: ", hdf_path, ". Please check it again")
        return

    # Divide the original image into 64x64 patches
    hdf_name_list = hdf_name.split(".")
    # For day image
    win_count = 0
    for (x,y,window) in sliding_window(img_day, step, size):
            if window.shape[0] != size[0] or window.shape[1] != size[1]:
                    continue

            img_cropped_name = hdf_name_list[0] + "." + hdf_name_list[1] + ".{}.tif".format(str(win_count).zfill(4))
            img_cropped = window
            geotransform2 = np.asarray(geotransform)
            geotransform2[0] = geotransform[0]+x*geotransform[1] # 1st coordinate of top left pixel of the image
            geotransform2[3] = geotransform[3]+y*geotransform[5] # 2nd coordinate of top left pixel of the image
            geotransform2=tuple(geotransform2)

            img_cropped_names.append(img_cropped_name)
            img_days.append(img_cropped)
            geotransform2s.append(geotransform2)

            win_count += 1

    # For night image
    win_count = 0
    for (x,y,window) in sliding_window(img_night, step, size):
        if window.shape[0] != size[0] or window.shape[1] != size[1]:
                continue
        # save_path = os.path.join(save_dir,img_cropped_name)
        img_cropped = window
        # np.save(save_path,img_cropped)
        img_nights.append(img_cropped)
        win_count += 1

    # Get the corresponding ndvi to the LST image
    ndvi_read_value = get_corresponding_ndvi(list_ndvi,ndvi_dir,hdf_name)
    # Ignore the current file in the processing if there are error when calculating the NDVI
    if ndvi_read_value is None :
        return
    red, NIR, NDVI, ndvi_projection, ndvi_geotransform = ndvi_read_value
    reds = []
    NIRs = []

    # Divide the original NDVI image into 256x256 patches
    win_count = 0
    for (x,y,window) in sliding_window(NDVI, 256, (256,256)):
            if window.shape[0] != 256 or window.shape[1] != 256:
                    continue

            img_cropped_name = img_cropped_names[win_count]
            image_name_list = img_cropped_name.split(".")
            image_name_list[0] = "MOD09GQ"
            save_name = '.'.join(image_name_list)
            ndvi_names.append(save_name)

            img_cropped = window
            ndvis.append(img_cropped)

            geotransform2 = np.asarray(ndvi_geotransform)
            geotransform2[0] = ndvi_geotransform[0]+x*ndvi_geotransform[1] # 1st coordinate of top left pixel of the image
            geotransform2[3] = ndvi_geotransform[3]+y*ndvi_geotransform[5] # 2nd coordinate of top left pixel of the image
            geotransform2=tuple(geotransform2)
            ndvi_geotransforms.append(geotransform2)
            win_count += 1

    # Save images and metadata into .tif file
    for i in range(len(img_cropped_names)):
        save_path = os.path.join(save_dir,img_cropped_names[i])
        succes = save_tif(save_path, img_days[i], img_nights[i], cols2, rows2, projection, geotransform2s[i])
        # Only save NDVI image if LST image has no cloud or sea pixels
        if(succes):
            # Only save ndvi images without NaN values
            if(len(ndvis[i][np.isnan(ndvis[i])])==0):
                save_path_ndvi = os.path.join(ndvi_save_path,ndvi_names[i])
                save_tif_MOD09GQ(save_path_ndvi, ndvis[i], 256, 256, ndvi_projection, ndvi_geotransforms[i])
            # Remove the saved LST images if the corresponding NDVI image has NaN values
            else:
                os.remove(save_path)

# %%
def get_corresponding_ndvi(list_ndvi,ndvi_dir,image_name):
    image_name_string = image_name.split(".")
    image_day = image_name_string[1]

    # Go through the list of reflectance files to get the corresponding one
    for ndvi in list_ndvi :
        ndvi_strings = ndvi.split(".")
        # Check that the year and day matches
        if(image_day == ndvi_strings[1]):
            ndvi_path = os.path.join(ndvi_dir, ndvi)
            if os.path.exists(ndvi_path):
                read_value = read_modis_MOD09GQ(ndvi_path)
                # Ignore if we can't open the hdf file
                if read_value is None :
                    print("Cannot handle this MODIS file: ", ndvi_path, ". Please check it again")
                    return None
                qa, red, NIR, cols, rows, projection, geotransform = read_value

                if qa is None or red is None or NIR is None:
                    print("Cannot handle this MODIS file: ", ndvi_path, ". Please check it again")
                    return None

                # Calculate the NDVI based on the RED and NIR reflectance bands
                ndvi = (NIR-red)/(NIR+red)
                return red, NIR, ndvi, projection, geotransform

    return None

# %%
def calculate_dates_daily(year, month):
    # Get the total number of days in the month
    total_days = calendar.monthrange(year, month)[1]
    startdates = ["{}-{}-01".format(str(year), str(month).zfill(2))]
    enddates = []
    for day in range(2, total_days + 1):
        enddates.append("{}-{}-{}".format(str(year), str(month).zfill(2), str(day).zfill(2)))
        startdates.append("{}-{}-{}".format(str(year), str(month).zfill(2), str(day).zfill(2)))
    enddates.append("{}-{}-{}".format(str(year), str(month).zfill(2), str(total_days).zfill(2)))
    return startdates, enddates

def download_and_process(year, month, products, tiles, n_processes, num_threads):
    # Calculate the dates in the given month in the given year to download daily images
    startdates, enddates = calculate_dates_daily(year, month)
    total_days = len(startdates)

    for product in products:
        pool = mp.Pool(n_processes)
        results = []

        # Download the daily images
        for i in range(total_days):
            res = pool.apply_async(MODIS_Downloader_DAILY, (startdates[i], enddates[i], year, product, tiles))
            results.append(res)

        # Ensure all downloads are complete
        for res in results:
            res.get()

        pool.close()
        pool.join()

    # Process both products and delete all HDF files in the end
    MODIS_Data_Preprocessing(year, products[0], num_threads, delete_files=True)

def main():
    parser = ArgumentParser()
    parser.add_argument('--year_begin', type=int, default=2020, help='Start year for data download')
    parser.add_argument('--year_end', type=int, default=2022, help='End year for data download')
    args, unknown = parser.parse_known_args()  # Use parse_known_args to handle unrecognized arguments

    years = list(np.arange(args.year_begin, args.year_end))
    products = ["MOD11A1.061", "MOD09GQ.061"]
    tiles = "h18v04"  # Tiles to download, France is in h17v04 and h18v04
    num_threads = 6
    n_processes = 18

    for year in years:
        for month in range(1, 13):
            download_and_process(year, month, products, tiles, n_processes, num_threads)

if __name__ == "__main__":
    main()
# Out:
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-11 to 2020-01-12Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-12 to 2020-01-13Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-02 to 2020-01-03Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-13 to 2020-01-14Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-08 to 2020-01-09Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-07 to 2020-01-08Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-14 to 2020-01-15Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-04 to 2020-01-05Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-01 to 2020-01-02Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-09 to 2020-01-10Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-10 to 2020-01-11
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-05 to 2020-01-06Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-06 to 2020-01-07Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-03 to 2020-01-04
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-15 to 2020-01-16
#
#
#
#
#
#
#
#
#
#
#
#
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-16 to 2020-01-17Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-17 to 2020-01-18
#
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-18 to 2020-01-19
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01-14 to 2020-01-15, time cost: 28.9587
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-01
start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-28 to 2020-01-29Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-17 to 2020-01-18, time cost: 25.6049Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-29 to 2020-01-30Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-09 to 2020-01-10, time cost: 25.6589
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-11 to 2020-01-12, time cost: 25.6691
#
#
#
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-31 to 2020-01-31
#
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-15 to 2020-01-16, time cost: 25.6631
#
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-01 to 2020-01-02, time cost: 25.7898
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-20 to 2020-01-21, time cost: 9.4920
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-21 to 2020-01-22, time cost: 8.7610
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-19 to 2020-01-20, time cost: 10.8210
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-22 to 2020-01-23, time cost: 9.1145
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-31 to 2020-01-31, time cost: 7.7458Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-24 to 2020-01-25, time cost: 8.7010
#
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-26 to 2020-01-27, time cost: 8.7967
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-25 to 2020-01-26, time cost: 9.3568
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-27 to 2020-01-28, time cost: 8.6814
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-23 to 2020-01-24, time cost: 9.5982
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-30 to 2020-01-31, time cost: 8.7975
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-28 to 2020-01-29, time cost: 8.9921
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-01-29 to 2020-01-30, time cost: 9.0381
# start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file: start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020007.h18v04.061.2021003154623.hdfstart to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020012.h18v04.061.2021003205004.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020018.h18v04.061.2021004043832.hdfstart to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  . Please check it again . Please check it again
#  start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:
# Cannot handle this MODIS file: Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020023.h18v04.061.2021004112716.hdf. Please check it again MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020028.h18v04.061.2021005001836.hdf
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020013.h18v04.061.2021003232435.hdf   Cannot handle this MODIS file:  . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020008.h18v04.061.2021003160103.hdf . Please check it again. Please check it again MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020019.h18v04.061.2021004062724.hdf
#
#  Cannot handle this MODIS file: Cannot handle this MODIS file: . Please check it again
# . Please check it again
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020014.h18v04.061.2021003233409.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020029.h18v04.061.2021005023238.hdf
# Cannot handle this MODIS file:   Cannot handle this MODIS file:   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020009.h18v04.061.2021003181430.hdfstart to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020001.h18v04.061.2021003092415.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020002.h18v04.061.2021003094902.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020003.h18v04.061.2021003111837.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020004.h18v04.061.2021003113312.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020005.h18v04.061.2021003133306.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020006.h18v04.061.2021003134154.hdf . Please check it again
# . Please check it again. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020024.h18v04.061.2021004114158.hdf
#
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020020.h18v04.061.2021004064320.hdf  . Please check it again. Please check it againCannot handle this MODIS file: Cannot handle this MODIS file:
# . Please check it again
#
# Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020030.h18v04.061.2021005032804.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020015.h18v04.061.2021004015535.hdfCannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020010.h18v04.061.2021003182412.hdf   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020025.h18v04.061.2021004170629.hdf. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020021.h18v04.061.2021004084852.hdf    . Please check it again
#
# . Please check it again. Please check it againCannot handle this MODIS file: . Please check it again
# Cannot handle this MODIS file:
#
# Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020031.h18v04.061.2021005042737.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020016.h18v04.061.2021004020952.hdf   Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020022.h18v04.061.2021004085417.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020026.h18v04.061.2021004172000.hdf . Please check it again . Please check it again
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020011.h18v04.061.2021003203846.hdf
# . Please check it again . Please check it again
#
# Cannot handle this MODIS file: . Please check it again Cannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020017.h18v04.061.2021004043304.hdf  . Please check it again
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020027.h18v04.061.2021004234849.hdf . Please check it again
# Using 1.0910s to process product = MOD11A1.061
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-02
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-24 to 2020-02-25
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-04 to 2020-02-05, time cost: 33.2292
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-25 to 2020-02-26
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-02 to 2020-02-03, time cost: 36.0441
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-26 to 2020-02-27
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-05 to 2020-02-06, time cost: 36.2723
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-27 to 2020-02-28
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-08 to 2020-02-09, time cost: 36.4468
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-09 to 2020-02-10, time cost: 36.5130Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-14 to 2020-02-15, time cost: 36.5157Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-28 to 2020-02-29
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-12 to 2020-02-13, time cost: 36.5377Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-29 to 2020-02-29
#
#
#
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-07 to 2020-02-08, time cost: 36.6806Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-11 to 2020-02-12, time cost: 36.6900Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-13 to 2020-02-14, time cost: 36.6716
#
#
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-18 to 2020-02-19, time cost: 36.6169
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-01 to 2020-02-02, time cost: 38.0571
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-29 to 2020-02-29, time cost: 7.4398
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-21 to 2020-02-22, time cost: 19.2172
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-19 to 2020-02-20, time cost: 20.1674
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-20 to 2020-02-21, time cost: 20.0328
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-22 to 2020-02-23, time cost: 16.6279
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-24 to 2020-02-25, time cost: 17.0559
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-25 to 2020-02-26, time cost: 16.9223
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-23 to 2020-02-24, time cost: 19.4473
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-28 to 2020-02-29, time cost: 13.8900
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-26 to 2020-02-27, time cost: 14.3979
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-02-27 to 2020-02-28, time cost: 14.4667
# start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file: start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020042.h18v04.061.2021005144734.hdfCannot handle this MODIS file:   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020037.h18v04.061.2021005101557.hdf . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020047.h18v04.061.2021005204027.hdf
# . Please check it again Cannot handle this MODIS file: . Please check it again
#
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020043.h18v04.061.2021005162315.hdfCannot handle this MODIS file:   . Please check it againstart to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020038.h18v04.061.2021005113543.hdfstart to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:
#    MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020052.h18v04.061.2021006020009.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020048.h18v04.061.2021005213853.hdfCannot handle this MODIS file:  start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020032.h18v04.061.2021005051938.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020033.h18v04.061.2021005061916.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020034.h18v04.061.2021005072016.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020035.h18v04.061.2021005082406.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020036.h18v04.061.2021005094123.hdf . Please check it again
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020057.h18v04.061.2021006153927.hdf. Please check it again. Please check it again
#
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020044.h18v04.061.2021005165352.hdfCannot handle this MODIS file: . Please check it againCannot handle this MODIS file: . Please check it again
#
# Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020053.h18v04.061.2021006054736.hdf. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020039.h18v04.061.2021005120237.hdfCannot handle this MODIS file:
#  . Please check it againCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020049.h18v04.061.2021005225223.hdf. Please check it again
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020058.h18v04.061.2021006161248.hdf
# Cannot handle this MODIS file:  Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020045.h18v04.061.2021005185631.hdf. Please check it again. Please check it again
#
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020054.h18v04.061.2021006070002.hdfCannot handle this MODIS file: . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020040.h18v04.061.2021005131215.hdfCannot handle this MODIS file:
#   . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020059.h18v04.061.2021006172352.hdfCannot handle this MODIS file: . Please check it again  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020050.h18v04.061.2021005234519.hdf. Please check it again
#
#
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020046.h18v04.061.2021005191103.hdfCannot handle this MODIS file: Cannot handle this MODIS file: . Please check it again  . Please check it again
#
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020041.h18v04.061.2021005135858.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020055.h18v04.061.2021006140448.hdfCannot handle this MODIS file:   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020060.h18v04.061.2021006180647.hdf . Please check it again
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2
ODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020085.h18v04.061.2021007142015.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020090.h18v04.061.2021007190742.hdf
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020080.h18v04.061.2021007102509.hdf   Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020070.h18v04.061.2021007023208.hdf. Please check it again. Please check it again . Please check it again
#
#
# . Please check it againCannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020075.h18v04.061.2021007061950.hdfCannot handle this MODIS file:  Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020081.h18v04.061.2021007110435.hdf . Please check it againCannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020071.h18v04.061.2021007032159.hdf
#   . Please check it again . Please check it againCannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020086.h18v04.061.2021007155836.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020091.h18v04.061.2021007192249.hdf
#   Cannot handle this MODIS file: . Please check it again. Please check it again
#
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020076.h18v04.061.2021007072135.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020082.h18v04.061.2021007120028.hdfCannot handle this MODIS file:    . Please check it again. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020087.h18v04.061.2021007160418.hdf
#
#  Cannot handle this MODIS file: . Please check it again
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020077.h18v04.061.2021007075155.hdf . Please check it again
# Using 1.4012s to process product = MOD11A1.061
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-06 to 2020-04-07
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-13 to 2020-04-14Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-16 to 2020-04-17Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-12 to 2020-04-13Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-07 to 2020-04-08Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-05 to 2020-04-06Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-09 to 2020-04-10Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-11 to 2020-04-12Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-03 to 2020-04-04Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-04 to 2020-04-05
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-10 to 2020-04-11Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-01 to 2020-04-02Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-14 to 2020-04-15Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-02 to 2020-04-03Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-18 to 2020-04-19
#
#
#
#
#
#
#
#
#
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-04-17 to 2020-04-18
#
# ...
# Using 1.9539s to process product = MOD11A1.061
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-01 to 2021-12-02Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-02 to 2021-12-03
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-15 to 2021-12-16Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-14 to 2021-12-15Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-11 to 2021-12-12Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-16 to 2021-12-17Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-08 to 2021-12-09Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-07 to 2021-12-08Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-10 to 2021-12-11Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-05 to 2021-12-06
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-03 to 2021-12-04
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-18 to 2021-12-19
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-13 to 2021-12-14Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-17 to 2021-12-18Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-06 to 2021-12-07Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-12 to 2021-12-13Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-04 to 2021-12-05Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-09 to 2021-12-10
#
#
#
#
#
#
#
#
#
#
#
#
#
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-08 to 2021-12-09, time cost: 18.7773
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-19 to 2021-12-20
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-02 to 2021-12-03, time cost: 20.3841
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-20 to 2021-12-21
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-05 to 2021-12-06, time cost: 20.8083
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-21 to 2021-12-22
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-07 to 2021-12-08, time cost: 21.3049
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-22 to 2021-12-23
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-09 to 2021-12-10, time cost: 21.6956
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-23 to 2021-12-24
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-16 to 2021-12-17, time cost: 21.8933
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-24 to 2021-12-25
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-11 to 2021-12-12, time cost: 22.0749
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-25 to 2021-12-26
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-14 to 2021-12-15, time cost: 22.4506
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-10 to 2021-12-11, time cost: 22.4552Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-26 to 2021-12-27
#
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-27 to 2021-12-28
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-18 to 2021-12-19, time cost: 22.5528Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-06 to 2021-12-07, time cost: 22.5925
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-04 to 2021-12-05, time cost: 22.6279
#
# Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-28 to 2021-12-29Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-29 to 2021-12-30Start to download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12-30 to 2021-12-31
# Finish download MODIS/MOD_2021_MOD11A1/hdfs_files From 2021-12
# Finish download MODIS/MOD_2021_MOD09GQ/hdfs_files From 2021-12-30 to 2021-12-31, time cost: 15.6813
# Finish download MODIS/MOD_2021_MOD09GQ/hdfs_files From 2021-12-28 to 2021-12-29, time cost: 17.0883
# start to processing MODIS/MOD_2021_MOD11A1/hdfs_files
# Cannot handle this MODIS file: start to processing MODIS/MOD_2021_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  start to processing MODIS/MOD_2021_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021341.h18v04.061.2021342104044.hdfstart to processing MODIS/MOD_2021_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021346.h18v04.061.2021347094248.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021352.h18v04.061.2021355023709.hdf  . Please check it again
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021357.h18v04.061.2021363202858.hdf. Please check it againCannot handle this MODIS file: . Please check it again
#
# . Please check it againstart to processing MODIS/MOD_2021_MOD11A1/hdfs_files
# Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021347.h18v04.061.2021348090239.hdfCannot handle this MODIS file:
#    Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021342.h18v04.061.2021343100434.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021362.h18v04.061.2022003233710.hdf  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021353.h18v04.061.2021355025918.hdf  . Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021358.h18v04.061.2021363212005.hdf . Please check it again
# . Please check it again . Please check it againstart to processing MODIS/MOD_2021_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021335.h18v04.061.2021338203844.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021336.h18v04.061.2021338204804.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021337.h18v04.061.2021340194141.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021338.h18v04.061.2021340204259.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021339.h18v04.061.2021340221437.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021340.h18v04.061.2021341085315.hdf . Please check it again
# Cannot handle this MODIS file:
#
# . Please check it again
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021348.h18v04.061.2021350181106.hdfCannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file:
#     Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021343.h18v04.061.2021344091328.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021363.h18v04.061.2022003234736.hdf. Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021354.h18v04.061.2021355111839.hdf
#  . Please check it again
# . Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021359.h18v04.061.2021364001818.hdf. Please check it again Cannot handle this MODIS file: . Please check it againCannot handle this MODIS file:
#
#
# Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021349.h18v04.061.2021350182137.hdfCannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021364.h18v04.061.2022004012855.hdf   Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021355.h18v04.061.2021356092351.hdf. Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021344.h18v04.061.2021345094057.hdf  . Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021360.h18v04.061.2022003213829.hdf
# . Please check it again Cannot handle this MODIS file:  . Please check it again
# . Please check it again
#
#  Cannot handle this MODIS file: Cannot handle this MODIS file:
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021350.h18v04.061.2021354235626.hdfCannot handle this MODIS file:  Cannot handle this MODIS file:   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021365.h18v04.061.2022004014730.hdf   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021356.h18v04.061.2021357093938.hdf. Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021361.h18v04.061.2022003220128.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021345.h18v04.061.2021346090444.hdf
#  . Please check it againCannot handle this MODIS file:    . Please check it again
# . Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021351.h18v04.061.2021355003548.hdf
# . Please check it again
#
# . Please check it again
# Using 9.5317s to process product = MOD11A1.061
