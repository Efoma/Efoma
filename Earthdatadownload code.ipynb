# %% [markdown]
# <a href="https://colab.research.google.com/github/Efoma/Efoma/blob/main/Earthdatadownload%20code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %%
pip install tifffile
# Out:
# Requirement already satisfied: tifffile in /usr/local/lib/python3.10/dist-packages (2024.7.24)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tifffile) (1.26.4)

# %%
pip install pymodis
# Out:
# Requirement already satisfied: pymodis in /usr/local/lib/python3.10/dist-packages (2.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pymodis) (1.26.4)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from pymodis) (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pymodis) (2.31.0)
# Requirement already satisfied: GDAL in /usr/local/lib/python3.10/dist-packages (from pymodis) (3.6.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pymodis) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pymodis) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pymodis) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pymodis) (2024.7.4)

# %%
pip install pymp-pypi
# Out:
# Requirement already satisfied: pymp-pypi in /usr/local/lib/python3.10/dist-packages (0.5.0)

# %%
import pymodis
print(pymodis.__version__)
# Out:
# 2.4.1

# %%
import os
from pymodis import downmodis
import numpy as np
import pymp
import time
from argparse import ArgumentParser
import shutil
import multiprocessing as mp
import calendar

# %%
import torch
import cv2
import torch.optim as optim
import torch.nn as nn
import math
from torchvision.utils import save_image
from torchvision import transforms
import torchvision.models as models
import torch.utils.model_zoo as model_zoo
from collections import OrderedDict
import torch.nn.functional as F

# %%
# VDSR and DMCN model

from math import sqrt

import torch.nn.init as init

# %%
def read_modis(hdf_path):
    # Implementation of read_modis function
    pass

# %%
def calculate_dates_daily(year, month):
    """
    This function calculate the dates of the days of the given month in the given year. Those dates will be used
    later to download the daily images from both the MODIS products
    """
    startdates = ["{}-{}-01".format(str(year),str(month).zfill(2))]
    enddates = []
    for day in range(2, total_days+1):
        enddates.append("{}-{}-{}".format(str(year),str(month).zfill(2),str(day).zfill(2)))
        startdates.append("{}-{}-{}".format(str(year),str(month).zfill(2),str(day).zfill(2)))

    if month != 12:
        enddates.append("{}-{}-01".format(str(year),str(month+1).zfill(2)))
    else:
        enddates.append("{}-01-01".format(str(year+1)))

    return startdates, enddates

# %%
def MODIS_Downloader(startdate, enddate, year, product, num_threads, tiles, user="efoma", password="Naijament@75"):
    sensor        = product.split(".")[0]
    hdfs_path     = 'MODIS/MOD_{}_{}/hdfs_files'.format(year,sensor)

    start_time = time.time()
    print("Start to download {} From {} to {}".format(hdfs_path, startdate,enddate))

    try:
        modisDown = downmodis.downModis(user=user,password=password,product=product,destinationFolder=hdfs_path, tiles=tiles, today=startdate, enddate=enddate)
        modisDown.connect()
        modisDown.downloadsAllDay()
    except:
        print("Download Error {} From {} to {}".format(hdfs_path, startdate,enddate))
    print("Finish download {} From {} to {}, time cost: {:.4f}".format(hdfs_path, startdate,enddate,time.time()-start_time))

# %%
def MODIS_Downloader_DAILY(startdate, enddate, year, product, tiles, user="efoma", password="Naijament@75"):
    sensor = product.split(".")[0]
    hdfs_path = 'MODIS/MOD_{}_{}/hdfs_files'.format(year,sensor)

    start_time = time.time()
    print("Start to download {} From {} to {}".format(hdfs_path, startdate,enddate))

    try:
        modisDown = downmodis.downModis(user=user,password=password,product=product,destinationFolder=hdfs_path, tiles=tiles, today=startdate, enddate=enddate)
        modisDown.connect()
        modisDown.downloadsAllDay()
    except:
        print("Download Error {} From {} to {}".format(hdfs_path, startdate,enddate))

    print("Finish download {} From {} to {}, time cost: {:.4f}".format(hdfs_path, startdate,enddate,time.time()-start_time))

# %%
def MODIS_Data_Preprocessing(year, product, num_threads, delete_files=False):
    """
    This function processes the hdf files in the given year and saves the NDVI and LST images in tiff format.
    If delete_files argument is set to True, the processed hdf files are deleted after.
    """
    sensor        = product.split(".")[0]
    root_dir      = 'MODIS/MOD_{}_{}'.format(year,sensor)
    hdfs_path     = os.path.join(root_dir, 'hdfs_files')
    tifs_1km_path = os.path.join(root_dir, 'tifs_files/1km')
    tifs_250m_path = os.path.join(root_dir, 'tifs_files/250m')

    os.makedirs(hdfs_path,exist_ok=1)

    # Create the save folders based on the processed sensor
    if sensor == 'MOD11A1':
        os.makedirs(tifs_1km_path,exist_ok=1)
    elif sensor == 'MOD13A2':
        os.makedirs(tifs_1km_path,exist_ok=1)
    elif sensor == "MOD13Q1":
        os.makedirs(tifs_250m_path,exist_ok=1)

    # Load the ndvi hdf files
    ndvi_folder = 'MODIS/MOD_{}_MOD09GQ'.format(year)
    ndvi_save_path = os.path.join(ndvi_folder, 'tifs_files/250m')
    ndvi_dir     = os.path.join(ndvi_folder, 'hdfs_files')
    os.makedirs(ndvi_save_path,exist_ok=1)

    list_ndvi =  os.listdir(ndvi_dir)
    indexes_to_delete=[]
    for index in range(len(list_ndvi)):
        if not list_ndvi[index].endswith('hdf'):
            indexes_to_delete.append(index)
    for j in sorted(indexes_to_delete,reverse=True):
        del list_ndvi[j]
    list_ndvi.sort()

    # Start processing file by file
    print("start to processing {}".format(hdfs_path))
    hdfs = os.listdir(hdfs_path)
    hdfs.sort()
    start_time = time.time()
    # Core images with multi-core
    with pymp.Parallel(num_threads) as p:
        for index in p.range(0, len(hdfs)):

            # Process only hdf files
            hdf = hdfs[index]
            if not hdf.endswith('hdf'): continue
            hdf_path = os.path.join(hdfs_path,hdf)

            # Process LST and NDVI images
            if sensor=='MOD11A1':
                process_hdf(hdf_path, hdf,tifs_1km_path,ndvi_save_path,list_ndvi,ndvi_dir, 64, (64,64))

    # Delete files ar the end
    if delete_files:
        shutil.rmtree(ndvi_dir, ignore_errors=False, onerror=None)
        shutil.rmtree(hdfs_path, ignore_errors=False, onerror=None)

    print("Using {:.4f}s to process product = {}".format(time.time()-start_time, product))

# %%
def process_hdf(hdf_path, hdf_name, save_dir,ndvi_save_path,list_ndvi,ndvi_dir,step=64,size=(64,64)):
    """
    INPUT:
    hdf_path = input LST image path to be processed | or hdf file path ("/a/b/c.hdf")
    hdf_name = name of the hdf file
    save_dir = directory for saving cropped images
    ndvi_save_path : Path to save the ndvi images
    ndvi_dir : path of the ndvi hdf files
    list_ndvi : List of the ndvi files
    step, size: parameters of "sliding_window()"
    OUTPUT: LST and NDVI images cropped from the hdf files, saved to save_dir in tiff format
    """
    if not hdf_path.endswith('hdf'):
        print("Not hdf file Sorry!")
        return
    # Open the LST hdf
    read_val = read_modis(hdf_path)
    # Ignore the file in the processing it there are errors when opening it
    if read_val is None:
        print("Cannot handle this MODIS file: ", hdf_path, ". Please check it again")
        return

    img_day, img_night, cols, rows, projection, geotransform = read_val

    img_days = []
    img_nights = []
    img_cropped_names = []
    ndvis = []
    ndvi_names = []
    ndvi_geotransforms = []
    geotransform2s = []
    cols2, rows2 = size

    if img_day is None or img_night is None:
        print("Cannot handle this MODIS file: ", hdf_path, ". Please check it again")
        return

    # Divide the original image into 64x64 patches
    hdf_name_list = hdf_name.split(".")
    # For day image
    win_count = 0
    for (x,y,window) in sliding_window(img_day, step, size):
            if window.shape[0] != size[0] or window.shape[1] != size[1]:
                    continue

            img_cropped_name = hdf_name_list[0] + "." + hdf_name_list[1] + ".{}.tif".format(str(win_count).zfill(4))
            img_cropped = window
            geotransform2 = np.asarray(geotransform)
            geotransform2[0] = geotransform[0]+x*geotransform[1] # 1st coordinate of top left pixel of the image
            geotransform2[3] = geotransform[3]+y*geotransform[5] # 2nd coordinate of top left pixel of the image
            geotransform2=tuple(geotransform2)

            img_cropped_names.append(img_cropped_name)
            img_days.append(img_cropped)
            geotransform2s.append(geotransform2)

            win_count += 1

    # For night image
    win_count = 0
    for (x,y,window) in sliding_window(img_night, step, size):
        if window.shape[0] != size[0] or window.shape[1] != size[1]:
                continue
        # save_path = os.path.join(save_dir,img_cropped_name)
        img_cropped = window
        # np.save(save_path,img_cropped)
        img_nights.append(img_cropped)
        win_count += 1

    # Get the corresponding ndvi to the LST image
    ndvi_read_value = get_corresponding_ndvi(list_ndvi,ndvi_dir,hdf_name)
    # Ignore the current file in the processing if there are error when calculating the NDVI
    if ndvi_read_value is None :
        return
    red, NIR, NDVI, ndvi_projection, ndvi_geotransform = ndvi_read_value
    reds = []
    NIRs = []

    # Divide the original NDVI image into 256x256 patches
    win_count = 0
    for (x,y,window) in sliding_window(NDVI, 256, (256,256)):
            if window.shape[0] != 256 or window.shape[1] != 256:
                    continue

            img_cropped_name = img_cropped_names[win_count]
            image_name_list = img_cropped_name.split(".")
            image_name_list[0] = "MOD09GQ"
            save_name = '.'.join(image_name_list)
            ndvi_names.append(save_name)

            img_cropped = window
            ndvis.append(img_cropped)

            geotransform2 = np.asarray(ndvi_geotransform)
            geotransform2[0] = ndvi_geotransform[0]+x*ndvi_geotransform[1] # 1st coordinate of top left pixel of the image
            geotransform2[3] = ndvi_geotransform[3]+y*ndvi_geotransform[5] # 2nd coordinate of top left pixel of the image
            geotransform2=tuple(geotransform2)
            ndvi_geotransforms.append(geotransform2)
            win_count += 1

    # Save images and metadata into .tif file
    for i in range(len(img_cropped_names)):
        save_path = os.path.join(save_dir,img_cropped_names[i])
        succes = save_tif(save_path, img_days[i], img_nights[i], cols2, rows2, projection, geotransform2s[i])
        # Only save NDVI image if LST image has no cloud or sea pixels
        if(succes):
            # Only save ndvi images without NaN values
            if(len(ndvis[i][np.isnan(ndvis[i])])==0):
                save_path_ndvi = os.path.join(ndvi_save_path,ndvi_names[i])
                save_tif_MOD09GQ(save_path_ndvi, ndvis[i], 256, 256, ndvi_projection, ndvi_geotransforms[i])
            # Remove the saved LST images if the corresponding NDVI image has NaN values
            else:
                os.remove(save_path)
# Out:
# Exception ignored in: <Finalize object, dead>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 695, in _terminate_pool
#     cls._help_stuff_finish(inqueue, task_handler, len(pool))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 675, in _help_stuff_finish
#     inqueue._rlock.acquire()
# KeyboardInterrupt:

# %%
def get_corresponding_ndvi(list_ndvi,ndvi_dir,image_name):
    image_name_string = image_name.split(".")
    image_day = image_name_string[1]

    # Go through the list of reflectance files to get the corresponding one
    for ndvi in list_ndvi :
        ndvi_strings = ndvi.split(".")
        # Check that the year and day matches
        if(image_day == ndvi_strings[1]):
            ndvi_path = os.path.join(ndvi_dir, ndvi)
            if os.path.exists(ndvi_path):
                read_value = read_modis_MOD09GQ(ndvi_path)
                # Ignore if we can't open the hdf file
                if read_value is None :
                    print("Cannot handle this MODIS file: ", ndvi_path, ". Please check it again")
                    return None
                qa, red, NIR, cols, rows, projection, geotransform = read_value

                if qa is None or red is None or NIR is None:
                    print("Cannot handle this MODIS file: ", ndvi_path, ". Please check it again")
                    return None

                # Calculate the NDVI based on the RED and NIR reflectance bands
                ndvi = (NIR-red)/(NIR+red)
                return red, NIR, ndvi, projection, geotransform

    return None

# %%
def calculate_dates_daily(year, month):
    # Get the total number of days in the month
    total_days = calendar.monthrange(year, month)[1]
    startdates = ["{}-{}-01".format(str(year), str(month).zfill(2))]
    enddates = []
    for day in range(2, total_days + 1):
        enddates.append("{}-{}-{}".format(str(year), str(month).zfill(2), str(day).zfill(2)))
        startdates.append("{}-{}-{}".format(str(year), str(month).zfill(2), str(day).zfill(2)))
    enddates.append("{}-{}-{}".format(str(year), str(month).zfill(2), str(total_days).zfill(2)))
    return startdates, enddates

def download_and_process(year, month, products, tiles, n_processes, num_threads):
    # Calculate the dates in the given month in the given year to download daily images
    startdates, enddates = calculate_dates_daily(year, month)
    total_days = len(startdates)

    for product in products:
        pool = mp.Pool(n_processes)
        results = []

        # Download the daily images
        for i in range(total_days):
            res = pool.apply_async(MODIS_Downloader_DAILY, (startdates[i], enddates[i], year, product, tiles))
            results.append(res)

        # Ensure all downloads are complete
        for res in results:
            res.get()

        pool.close()
        pool.join()

    # Process both products and delete all HDF files in the end
    MODIS_Data_Preprocessing(year, products[0], num_threads, delete_files=False)

def main():
    parser = ArgumentParser()
    parser.add_argument('--year_begin', type=int, default=2020, help='Start year for data download')
    parser.add_argument('--year_end', type=int, default=2022, help='End year for data download')
    args, unknown = parser.parse_known_args()  # Use parse_known_args to handle unrecognized arguments

    years = list(np.arange(args.year_begin, args.year_end))
    products = ["MOD11A1.061", "MOD09GQ.061"]
    tiles = "h18v04"  # Tiles to download, France is in h17v04 and h18v04
    num_threads = 6
    n_processes = 18

    for year in years:
        for month in range(1, 13):
            download_and_process(year, month, products, tiles, n_processes, num_threads)

if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
#  . Please check it againCannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file:  . Please check it again
#
# Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020077.h18v04.061.2021007075155.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020280.h18v04.061.2021017091526.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020229.h18v04.061.2021014030135.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020179.h18v04.061.2021012053407.hdf   . Please check it again . Please check it again. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020129.h18v04.061.2021009024156.hdf
# . Please check it again
#
# Cannot handle this MODIS file: Cannot handle this MODIS file:
# Cannot handle this MODIS file: . Please check it again Cannot handle this MODIS file:
#  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020078.h18v04.061.2021007085043.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020230.h18v04.061.2021014035759.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020281.h18v04.061.2021017101922.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020180.h18v04.061.2021012080614.hdf     . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020130.h18v04.061.2021009034757.hdf. Please check it again. Please check it again. Please check it again
#
#
#
# . Please check it againCannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file:
#    MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020231.h18v04.061.2021014044320.hdf Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020282.h18v04.061.2021017105027.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020079.h18v04.061.2021007092334.hdf    MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020181.h18v04.061.2021012081752.hdf. Please check it again . Please check it again. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020131.h18v04.061.2021009042308.hdf
#
# . Please check it again
#  Cannot handle this MODIS file: Cannot handle this MODIS file:
# Cannot handle this MODIS file: . Please check it again Cannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020232.h18v04.061.2021014054148.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020080.h18v04.061.2021007102509.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020283.h18v04.061.2021017115757.hdf Cannot handle this MODIS file:   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020182.h18v04.061.2021012101758.hdf  . Please check it again. Please check it again. Please check it again MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020132.h18v04.061.2021009052342.hdf
#
# . Please check it again
# Cannot handle this MODIS file: Cannot handle this MODIS file: . Please check it again
# Cannot handle this MODIS file:
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020284.h18v04.061.2021017122229.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020081.h18v04.061.2021007110435.hdfCannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020233.h18v04.061.2021014064218.hdf    MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020183.h18v04.061.2021012102420.hdf. Please check it again. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020133.h18v04.061.2021009055507.hdf . Please check it again
#
#
# . Please check it againCannot handle this MODIS file: . Please check it againCannot handle this MODIS file: Cannot handle this MODIS file:
#   Cannot handle this MODIS file:
#  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020184.h18v04.061.2021012123435.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020082.h18v04.061.2021007120028.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020285.h18v04.061.2021017132437.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020234.h18v04.061.2021014071759.hdfCannot handle this MODIS file:     . Please check it again . Please check it again. Please check it again. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020134.h18v04.061.2021009072123.hdf
#
#
#
#  Cannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file:  Cannot handle this MODIS file: . Please check it again
#   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020235.h18v04.061.2021014083309.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020185.h18v04.061.2021012124010.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020083.h18v04.061.2021007123631.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020286.h18v04.061.2021017134931.hdf  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020135.h18v04.061.2021009074637.hdf   . Please check it again
# . Please check it again. Please check it again. Please check it again. Please check it again
#
# Cannot handle this MODIS file:
#
# Cannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file:     MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020136.h18v04.061.2021009085129.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020186.h18v04.061.2021012141640.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020287.h18v04.061.2021017145348.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020084.h18v04.061.2021007141543.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020236.h18v04.061.2021014090222.hdf   . Please check it again. Please check it again . Please check it again. Please check it again
#
# . Please check it again
# Cannot handle this MODIS file:
#
# Cannot handle this MODIS file:  Cannot handle this MODIS file: Cannot handle this MODIS file:  Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020187.h18v04.061.2021012142911.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020288.h18v04.061.2021017152708.hdf  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020085.h18v04.061.2021007142015.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020237.h18v04.061.2021014100932.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020137.h18v04.061.2021009092626.hdf . Please check it again . Please check it again . Please check it again
#
# . Please check it again. Please check it again
# Cannot handle this MODIS file:
# Cannot handle this MODIS file:
# Cannot handle this MODIS file: Cannot handle this MODIS file:  Cannot handle this MODIS file:    MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020289.h18v04.061.2021017163701.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020086.h18v04.061.2021007155836.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020238.h18v04.061.2021014104643.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020188.h18v04.061.2021012160200.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020138.h18v04.061.2021009102632.hdf. Please check it again
#  . Please check it again. Please check it againCannot handle this MODIS file: . Please check it again. Please check it again
#
#
#
# Cannot handle this MODIS file:  Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020290.h18v04.061.2021017165728.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020087.h18v04.061.2021007160418.hdf Cannot handle this MODIS file: . Please check it again   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020189.h18v04.061.2021012161901.hdf
#  Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020239.h18v04.061.2021014114746.hdf. Please check it again
#  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020088.h18v04.061.2021007173246.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020139.h18v04.061.2021009110247.hdfCannot handle this MODIS file:     MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020291.h18v04.061.2021017180538.hdf. Please check it again
# . Please check it again. Please check it again. Please check it again. Please check it againCannot handle this MODIS file:
#
#
# Cannot handle this MODIS file:  Cannot handle this MODIS file:
#   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020089.h18v04.061.2021007174435.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020292.h18v04.061.2021017182712.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020140.h18v04.061.2021009120809.hdf  . Please check it againCannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020240.h18v04.061.2021014122249.hdf   . Please check it againCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020190.h18v04.061.2021012173113.hdf. Please check it again
#
#  . Please check it againCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020090.h18v04.061.2021007190742.hdfCannot handle this MODIS file:    . Please check it again
# . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020141.h18v04.061.2021009123334.hdf
#
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020293.h18v04.061.2021017192731.hdf Cannot handle this MODIS file: Cannot handle this MODIS file: . Please check it again Cannot handle this MODIS file:
#  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020091.h18v04.061.2021007192249.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020241.h18v04.061.2021014132432.hdfCannot handle this MODIS file: . Please check it again  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020191.h18v04.061.2021012183449.hdf. Please check it again  . Please check it again
#
# Cannot handle this MODIS file: . Please check it again
#
# Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020242.h18v04.061.2021014140653.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020142.h18v04.061.2021009134358.hdfCannot handle this MODIS file:     . Please check it again. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020294.h18v04.061.2021017195945.hdf
#  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020092.h18v04.061.2021007204334.hdf
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020192.h18v04.061.2021012190028.hdf  Cannot handle this MODIS file:  . Please check it again . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020143.h18v04.061.2021009140543.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020243.h18v04.061.2021014150031.hdf. Please check it again
#
# . Please check it again
# Cannot handle this MODIS file: Cannot handle this MODIS file:
#  Cannot handle this MODIS file:  . Please check it again MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020093.h18v04.061.2021007210532.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020295.h18v04.061.2021017204825.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020193.h18v04.061.2021012200431.hdf
#  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020144.h18v04.061.2021010220919.hdfCannot handle this MODIS file: . Please check it again. Please check it again . Please check it again
#
#
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020244.h18v04.061.2021014154837.hdf. Please check it againCannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file:
#    Cannot handle this MODIS file:   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020145.h18v04.061.2021010221540.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020194.h18v04.061.2021012202558.hdf. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020296.h18v04.061.2021017213039.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020094.h18v04.061.2021007221550.hdf
#    . Please check it again. Please check it again. Please check it againCannot handle this MODIS file: . Please check it again
#
#
#
# Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020245.h18v04.061.2021014163854.hdfCannot handle this MODIS file: Cannot handle this MODIS file:   . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020146.h18v04.061.2021010235026.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020195.h18v04.061.2021012213652.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020297.h18v04.061.2021017221429.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020095.h18v04.061.2021007224031.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020246.h18v04.061.2021014172554.hdf    . Please check it again. Please check it again. Please check it again. Please check it again. Please check it again
#
#
#
# Cannot handle this MODIS file:
# Cannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file:   Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020247.h18v04.061.2021014182234.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020196.h18v04.061.2021012215234.hdf  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020096.h18v04.061.2021008001309.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020147.h18v04.061.2021010235615.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020298.h18v04.061.2021017230107.hdf  . Please check it again. Please check it again . Please check it again. Please check it again
#
# . Please check it againCannot handle this MODIS file:
#
# Cannot handle this MODIS file:
# Cannot handle this MODIS file: Cannot handle this MODIS file:   Cannot handle this MODIS file:   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020197.h18v04.061.2021012231319.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020248.h18v04.061.2021014191622.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020148.h18v04.061.2021011011740.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020097.h18v04.061.2021008002444.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020299.h18v04.061.2021017234058.hdf . Please check it again . Please check it again . Please check it again
# . Please check it again
# . Please check it again
# Cannot handle this MODIS file:
# Cannot handle this MODIS file:
#  Cannot handle this MODIS file: Cannot handle this MODIS file:  Cannot handle this MODIS file:    MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020198.h18v04.061.2021012232052.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020300.h18v04.061.2021018003544.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020249.h18v04.061.2021014201012.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020149.h18v04.061.2021011013927.hdf. Please check it again  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020098.h18v04.061.2021008014539.hdf
#  . Please check it again Cannot handle this MODIS file: . Please check it again. Please check it again. Please check it again
#
#
#
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020301.h18v04.061.2021018010421.hdfCannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file:  . Please check it again    MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020150.h18v04.061.2021011025524.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020099.h18v04.061.2021008020655.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020250.h18v04.061.2021014211513.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020199.h18v04.061.2021013004154.hdf
#     Cannot handle this MODIS file: Using 5.2564s to process product = MOD11A1.061
# . Please check it again. Please check it again. Please check it again. Please check it again
#
#
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020302.h18v04.061.2021018020332.hdf
# Cannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file:  Cannot handle this MODIS file:    . Please check it again
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020100.h18v04.061.2021008032202.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020151.h18v04.061.2021011031419.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020251.h18v04.061.2021014221417.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020200.h18v04.061.2021013005522.hdf  Cannot handle this MODIS file:   . Please check it again. Please check it again . Please check it again. Please check it again
#
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020303.h18v04.061.2021018023635.hdf
#
#  . Please check it again
# Cannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file:  Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020152.h18v04.061.2021011042725.hdfCannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020101.h18v04.061.2021008035045.hdf    MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020252.h18v04.061.2021014230722.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020201.h18v04.061.2021013020721.hdf. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020304.h18v04.061.2021018033311.hdf. Please check it again
#
# . Please check it againCannot handle this MODIS file: . Please check it againCannot handle this MODIS file: . Please check it again
#
#  Cannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020102.h18v04.061.2021008050221.hdf Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020153.h18v04.061.2021011045947.hdf Cannot handle this MODIS file: . Please check it again  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020253.h18v04.061.2021014235556.hdf
#  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020202.h18v04.061.2021013022812.hdf  . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020305.h18v04.061.2021018040609.hdf. Please check it again. Please check it again
#
# Cannot handle this MODIS file:
# . Please check it again
# Cannot handle this MODIS file:   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020203.h18v04.061.2021013033639.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020254.h18v04.061.2021015005916.hdf  . Please check it again. Please check it again
# Cannot handle this MODIS file:
# Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020255.h18v04.061.2021015013906.hdf  . Please check it again
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020204.h18v04.061.2021013042751.hdf . Please check it again
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-04 to 2020-11-05Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-02 to 2020-11-03Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-03 to 2020-11-04Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-18 to 2020-11-19Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-05 to 2020-11-06Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-06 to 2020-11-07Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-01 to 2020-11-02Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-09 to 2020-11-10Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-12 to 2020-11-13Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-17 to 2020-11-18Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-10 to 2020-11-11Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-16 to 2020-11-17Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-07 to 2020-11-08Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-14 to 2020-11-15Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-15 to 2020-11-16Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-08 to 2020-11-09
#
#
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-11 to 2020-11-12
#
#
#
#
#
#
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-13 to 2020-11-14
#
#
#
#
#
#
#
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-12 to 2020-11-13, time cost: 23.9508
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-19 to 2020-11-20
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-16 to 2020-11-17, time cost: 36.0711
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-20 to 2020-11-21
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-17 to 2020-11-18, time cost: 36.5554
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-21 to 2020-11-22
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-02 to 2020-11-03, time cost: 36.8582
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-06 to 2020-11-07, time cost: 36.8871Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-22 to 2020-11-23
#
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-23 to 2020-11-24
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-09 to 2020-11-10, time cost: 37.2705
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-24 to 2020-11-25
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-13 to 2020-11-14, time cost: 37.9321
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-25 to 2020-11-26
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-14 to 2020-11-15, time cost: 38.0354
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-26 to 2020-11-27
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-18 to 2020-11-19, time cost: 38.3059Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-03 to 2020-11-04, time cost: 38.3510
#
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-28 to 2020-11-29Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-15 to 2020-11-16, time cost: 38.3488Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-27 to 2020-11-28
#
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-05 to 2020-11-06, time cost: 38.4610Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-11 to 2020-11-12, time cost: 38.3780Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-04 to 2020-11-05, time cost: 38.4739
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-07 to 2020-11-08, time cost: 38.4751Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-29 to 2020-11-30
#
#
#
#
# Start to download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-30 to 2020-11-30Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-08 to 2020-11-09, time cost: 38.5410Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-10 to 2020-11-11, time cost: 38.5590
#
#
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-01 to 2020-11-02, time cost: 39.7641
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-19 to 2020-11-20, time cost: 20.7731
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-30 to 2020-11-30, time cost: 19.5469
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-22 to 2020-11-23, time cost: 23.3609
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-24 to 2020-11-25, time cost: 23.0029
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-29 to 2020-11-30, time cost: 22.5569Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-25 to 2020-11-26, time cost: 23.0206
#
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-21 to 2020-11-22, time cost: 24.5150
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-20 to 2020-11-21, time cost: 25.4687
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-27 to 2020-11-28, time cost: 23.3373
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-26 to 2020-11-27, time cost: 23.6708
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-28 to 2020-11-29, time cost: 23.4580
# Finish download MODIS/MOD_2020_MOD11A1/hdfs_files From 2020-11-23 to 2020-11-24, time cost: 25.1601
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-02 to 2020-11-03Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-03 to 2020-11-04Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-01 to 2020-11-02Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-04 to 2020-11-05
#
#
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-09 to 2020-11-10Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-11 to 2020-11-12Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-12 to 2020-11-13Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-18 to 2020-11-19Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-15 to 2020-11-16Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-10 to 2020-11-11Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-17 to 2020-11-18Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-13 to 2020-11-14
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-14 to 2020-11-15
#
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-16 to 2020-11-17Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-05 to 2020-11-06Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-06 to 2020-11-07
#
#
#
#
#
#
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-08 to 2020-11-09Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-07 to 2020-11-08
#
#
#
#
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-17 to 2020-11-18, time cost: 38.4265
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-19 to 2020-11-20
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-10 to 2020-11-11, time cost: 38.9301
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-20 to 2020-11-21
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-15 to 2020-11-16, time cost: 40.8681
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-21 to 2020-11-22
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-05 to 2020-11-06, time cost: 44.4108
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-22 to 2020-11-23
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-08 to 2020-11-09, time cost: 44.5521
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-23 to 2020-11-24
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-07 to 2020-11-08, time cost: 44.7988
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-24 to 2020-11-25
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-02 to 2020-11-03, time cost: 45.0871
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-25 to 2020-11-26
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-16 to 2020-11-17, time cost: 45.2689Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-12 to 2020-11-13, time cost: 45.3052
#
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-14 to 2020-11-15, time cost: 45.3178Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-26 to 2020-11-27Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-27 to 2020-11-28
#
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-28 to 2020-11-29
#
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-04 to 2020-11-05, time cost: 45.7047
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-29 to 2020-11-30
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-11 to 2020-11-12, time cost: 46.0925
# Start to download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-30 to 2020-11-30
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-09 to 2020-11-10, time cost: 46.3143
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-06 to 2020-11-07, time cost: 46.6953
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-13 to 2020-11-14, time cost: 47.0560
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-18 to 2020-11-19, time cost: 47.3303
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-03 to 2020-11-04, time cost: 47.4193
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-01 to 2020-11-02, time cost: 54.1345
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-30 to 2020-11-30, time cost: 13.0280
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-20 to 2020-11-21, time cost: 20.2907
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-19 to 2020-11-20, time cost: 20.9465
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-21 to 2020-11-22, time cost: 18.6356
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-22 to 2020-11-23, time cost: 19.8534
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-27 to 2020-11-28, time cost: 19.7406
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-23 to 2020-11-24, time cost: 20.7533
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-29 to 2020-11-30, time cost: 19.7646
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-24 to 2020-11-25, time cost: 21.1072
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-25 to 2020-11-26, time cost: 21.4229
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-26 to 2020-11-27, time cost: 22.8089
# Finish download MODIS/MOD_2020_MOD09GQ/hdfs_files From 2020-11-28 to 2020-11-29, time cost: 26.3426
# start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020057.h18v04.061.2021006153927.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020113.h18v04.061.2021008132641.hdf start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:   . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020169.h18v04.061.2021011191446.hdfstart to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file: . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020225.h18v04.061.2021013232129.hdfCannot handle this MODIS file:  start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020001.h18v04.061.2021003092415.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020002.h18v04.061.2021003094902.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020003.h18v04.061.2021003111837.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020004.h18v04.061.2021003113312.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020005.h18v04.061.2021003133306.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020006.h18v04.061.2021003134154.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020007.h18v04.061.2021003154623.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020008.h18v04.061.2021003160103.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020009.h18v04.061.2021003181430.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020010.h18v04.061.2021003182412.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020011.h18v04.061.2021003203846.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020012.h18v04.061.2021003205004.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020013.h18v04.061.2021003232435.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020014.h18v04.061.2021003233409.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020015.h18v04.061.2021004015535.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020016.h18v04.061.2021004020952.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020017.h18v04.061.2021004043304.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020018.h18v04.061.2021004043832.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020019.h18v04.061.2021004062724.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020020.h18v04.061.2021004064320.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020021.h18v04.061.2021004084852.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020022.h18v04.061.2021004085417.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020023.h18v04.061.2021004112716.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020024.h18v04.061.2021004114158.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020025.h18v04.061.2021004170629.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020026.h18v04.061.2021004172000.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020027.h18v04.061.2021004234849.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020028.h18v04.061.2021005001836.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020029.h18v04.061.2021005023238.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020030.h18v04.061.2021005032804.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020031.h18v04.061.2021005042737.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020032.h18v04.061.2021005051938.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020033.h18v04.061.2021005061916.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020034.h18v04.061.2021005072016.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020035.h18v04.061.2021005082406.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020036.h18v04.061.2021005094123.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020037.h18v04.061.2021005101557.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020038.h18v04.061.2021005113543.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020039.h18v04.061.2021005120237.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020040.h18v04.061.2021005131215.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020041.h18v04.061.2021005135858.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020042.h18v04.061.2021005144734.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020043.h18v04.061.2021005162315.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020044.h18v04.061.2021005165352.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020045.h18v04.061.2021005185631.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020046.h18v04.061.2021005191103.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020047.h18v04.061.2021005204027.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020048.h18v04.061.2021005213853.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020049.h18v04.061.2021005225223.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020050.h18v04.061.2021005234519.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020051.h18v04.061.2021006010033.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020052.h18v04.061.2021006020009.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020053.h18v04.061.2021006054736.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020054.h18v04.061.2021006070002.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020055.h18v04.061.2021006140448.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020056.h18v04.061.2021006142638.hdf . Please check it again
#  start to processing MODIS/MOD_2020_MOD11A1/hdfs_files
# Cannot handle this MODIS file:   . Please check it again
#
# Cannot handle this MODIS file: . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020114.h18v04.061.2021008150424.hdf . Please check it again
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020058.h18v04.061.2021006161248.hdf
# Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020281.h18v04.061.2021017101922.hdfCannot handle this MODIS file:  . Please check it again
#  . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020170.h18v04.061.2021011202704.hdfCannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020226.h18v04.061.2021014001515.hdf
#  Cannot handle this MODIS file: Cannot handle this MODIS file: . Please check it again    MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020282.h18v04.061.2021017105027.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020115.h18v04.061.2021008151121.hdf
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020059.h18v04.061.2021006172352.hdf . Please check it again. Please check it again Cannot handle this MODIS file:
# . Please check it again. Please check it again
#  Cannot handle this MODIS file:
#  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020171.h18v04.061.2021011211308.hdfCannot handle this MODIS file:
#   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020283.h18v04.061.2021017115757.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020227.h18v04.061.2021014011235.hdf. Please check it againCannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020060.h18v04.061.2021006180647.hdf. Please check it againCannot handle this MODIS file:
#  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020116.h18v04.061.2021008164111.hdf. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020172.h18v04.061.2021011231329.hdfCannot handle this MODIS file:
#    . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020228.h18v04.061.2021014021345.hdfCannot handle this MODIS file:
#  . Please check it again . Please check it againCannot handle this MODIS file: . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020284.h18v04.061.2021017122229.hdf
#
#   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020061.h18v04.061.2021006190426.hdf
# Cannot handle this MODIS file: . Please check it againCannot handle this MODIS file: Cannot handle this MODIS file:
#  Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020229.h18v04.061.2021014030135.hdf    . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020285.h18v04.061.2021017132437.hdf. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020173.h18v04.061.2021011232356.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020117.h18v04.061.2021008165617.hdf
#    . Please check it again
# . Please check it again
# Cannot handle this MODIS file: . Please check it againCannot handle this MODIS file:
# Cannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020062.h18v04.061.2021006195205.hdf Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020118.h18v04.061.2021008183140.hdfCannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020230.h18v04.061.2021014035759.hdf  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020174.h18v04.061.2021012011422.hdf . Please check it again . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020286.h18v04.061.2021017134931.hdf
#   Cannot handle this MODIS file:
# . Please check it again. Please check it again. Please check it again
#  Cannot handle this MODIS file: Cannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020119.h18v04.061.2021008183718.hdf
#   Cannot handle this MODIS file:  Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020063.h18v04.061.2021006204653.hdf . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020287.h18v04.061.2021017145348.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020231.h18v04.061.2021014044320.hdf  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020175.h18v04.061.2021012012024.hdf
# . Please check it again. Please check it again . Please check it again
#
# Cannot handle this MODIS file:
# . Please check it againCannot handle this MODIS file:  Cannot handle this MODIS file: Cannot handle this MODIS file:
#   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020288.h18v04.061.2021017152708.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020120.h18v04.061.2021008200702.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020232.h18v04.061.2021014054148.hdf   . Please check it again MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020064.h18v04.061.2021006212540.hdf. Please check it again
# . Please check it againCannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020176.h18v04.061.2021012025509.hdf
#   . Please check it again. Please check it againCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020289.h18v04.061.2021017163701.hdfCannot handle this MODIS file:
#
#  Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020233.h18v04.061.2021014064218.hdfCannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020121.h18v04.061.2021008202017.hdf  . Please check it again  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020177.h18v04.061.2021012033120.hdf. Please check it again
#
#  . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020065.h18v04.061.2021006223123.hdfCannot handle this MODIS file: Cannot handle this MODIS file:  . Please check it again
#  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020290.h18v04.061.2021017165728.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020234.h18v04.061.2021014071759.hdf
# . Please check it again. Please check it againCannot handle this MODIS file:
# Cannot handle this MODIS file:  Cannot handle this MODIS file:
#  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020291.h18v04.061.2021017180538.hdf. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020122.h18v04.061.2021008214510.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020178.h18v04.061.2021012045431.hdfCannot handle this MODIS file:  . Please check it again
# Cannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020066.h18v04.061.2021006231738.hdf. Please check it againCannot handle this MODIS file:  . Please check it again  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020292.h18v04.061.2021017182712.hdf
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020235.h18v04.061.2021014083309.hdfCannot handle this MODIS file:
#  . Please check it againCannot handle this MODIS file:
# . Please check it again. Please check it again
#  Cannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020123.h18v04.061.2021008214906.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020179.h18v04.061.2021012053407.hdf  Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020293.h18v04.061.2021017192731.hdf MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020067.h18v04.061.2021007001054.hdf . Please check it again. Please check it again
#
# . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020236.h18v04.061.2021014090222.hdfCannot handle this MODIS file: . Please check it againCannot handle this MODIS file:
#
#   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020124.h18v04.061.2021008231139.hdfCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020180.h18v04.061.2021012080614.hdf. Please check it againCannot handle this MODIS file:
#   . Please check it again. Please check it againCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020294.h18v04.061.2021017195945.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020068.h18v04.061.2021007005325.hdf . Please check it again
#
#
# Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020237.h18v04.061.2021014100932.hdfCannot handle this MODIS file: . Please check it again
# Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020125.h18v04.061.2021008232646.hdf. Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020181.h18v04.061.2021012081752.hdf
#   . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020295.h18v04.061.2021017204825.hdfCannot handle this MODIS file: . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020069.h18v04.061.2021007014550.hdfCannot handle this MODIS file:
#
#  . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020238.h18v04.061.2021014104643.hdf. Please check it againCannot handle this MODIS file: Cannot handle this MODIS file:
#
#  Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020126.h18v04.061.2021009004444.hdfCannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020182.h18v04.061.2021012101758.hdf. Please check it again
#   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020296.h18v04.061.2021017213039.hdfMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020070.h18v04.061.2021007023208.hdf. Please check it againCannot handle this MODIS file: . Please check it again
#
# . Please check it againCannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020239.h18v04.061.2021014114746.hdf. Please check it againCannot handle this MODIS file:
# Cannot handle this MODIS file:   MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020127.h18v04.061.2021009010846.hdf. Please check it againCannot handle this MODIS file:  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020183.h18v04.061.2021012102420.hdf  MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020297.h18v04.061.2021017221429.hdf
# Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020071.h18v04.061.2021007032159.hdf. Please check it again  . Please check it again
#  . Please check it again   Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020128.h18v04.061.2021009021304.hdf . Please check it again Cannot handle this MODIS file: . Please check it againMODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020241.h18v04.061.2021014132432.hdf. Please check it againCannot handle this MODIS file:
# MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020129.h18v04.061.2021009024156.hdf. Please check it again Cannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020242.h18v04.061.2021014140653.hdf Cannot handle this MODIS file:  Cannot handle this MODIS file:
# . Please check it againCannot handle this MODIS file: MODIS/MOD_2020_MOD11A1/hdfs_files/MOD11A1.A2020240.h18v04.061.2021014122249.hdf
#
#
# ...
#  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021162.h18v04.061.2021163090258.hdf MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021099.h18v04.061.2021100104533.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021343.h18v04.061.2021344091328.hdfCannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021283.h18v04.061.2021284084715.hdf   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021219.h18v04.061.2021220090426.hdf. Please check it again. Please check it again. Please check it again
#
#
# . Please check it againCannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file: . Please check it again
#
#   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021100.h18v04.061.2021101085207.hdfCannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021344.h18v04.061.2021345094057.hdf MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021163.h18v04.061.2021164090712.hdf. Please check it again
#  Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021284.h18v04.061.2021285085900.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021220.h18v04.061.2021221093608.hdf . Please check it again. Please check it again
#
#  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021101.h18v04.061.2021102090839.hdfCannot handle this MODIS file: . Please check it again. Please check it againCannot handle this MODIS file:
#
#  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021164.h18v04.061.2021165091248.hdf. Please check it againCannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021345.h18v04.061.2021346090444.hdf
#    Cannot handle this MODIS file: . Please check it again MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021221.h18v04.061.2021222095035.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021285.h18v04.061.2021286084747.hdf . Please check it again
# . Please check it again  . Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021102.h18v04.061.2021103090452.hdf
# Cannot handle this MODIS file:
#  Cannot handle this MODIS file:
# Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021165.h18v04.061.2021166092422.hdf . Please check it again Cannot handle this MODIS file:
# . Please check it again
#  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021346.h18v04.061.2021347094248.hdfCannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021286.h18v04.061.2021287085704.hdf . Please check it again MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021222.h18v04.061.2021223095851.hdf
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021287.h18v04.061.2021288151006.hdfCannot handle this MODIS file:  . Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021103.h18v04.061.2021104134857.hdf . Please check it again
#  Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021288.h18v04.061.2021289085931.hdf
#   . Please check it again. Please check it again
# Cannot handle this MODIS file: . Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021166.h18v04.061.2021167085416.hdf
#
# . Please check it againCannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021347.h18v04.061.2021348090239.hdf Cannot handle this MODIS file:
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021104.h18v04.061.2021107041728.hdf  . Please check it againCannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021223.h18v04.061.2021224091512.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021289.h18v04.061.2021292212721.hdf
#   . Please check it againCannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021167.h18v04.061.2021168091047.hdf . Please check it again . Please check it again. Please check it again
#
#  Cannot handle this MODIS file:
#
# Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021348.h18v04.061.2021350181106.hdf Cannot handle this MODIS file:   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021105.h18v04.061.2021107090818.hdf  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021168.h18v04.061.2021169091215.hdf MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021224.h18v04.061.2021225092634.hdf. Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021290.h18v04.061.2021292213255.hdf  . Please check it again
#
# . Please check it again. Please check it againCannot handle this MODIS file: . Please check it againCannot handle this MODIS file:
#
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021106.h18v04.061.2021107131828.hdf
# Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021349.h18v04.061.2021350182137.hdfCannot handle this MODIS file:   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021225.h18v04.061.2021226124654.hdf   . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021107.h18v04.061.2021108090255.hdf . Please check it again MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021169.h18v04.061.2021170085741.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021291.h18v04.061.2021293000153.hdf. Please check it again. Please check it again
#
# Cannot handle this MODIS file: . Please check it again. Please check it again
#
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021350.h18v04.061.2021354235626.hdf . Please check it againCannot handle this MODIS file: Cannot handle this MODIS file:
#  Cannot handle this MODIS file:
#  Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021292.h18v04.061.2021293085758.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021351.h18v04.061.2021355003548.hdf  . Please check it again . Please check it again
# Cannot handle this MODIS file:
#  Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021293.h18v04.061.2021294085811.hdf MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021352.h18v04.061.2021355023709.hdfCannot handle this MODIS file:  . Please check it again
# . Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021226.h18v04.061.2021227103312.hdfCannot handle this MODIS file:
#   Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021294.h18v04.061.2021299053634.hdf MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021108.h18v04.061.2021110062402.hdf  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021353.h18v04.061.2021355025918.hdf. Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021170.h18v04.061.2021171091109.hdf. Please check it again
#
# . Please check it again
# Cannot handle this MODIS file:  Cannot handle this MODIS file: Cannot handle this MODIS file:   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021109.h18v04.061.2021110234653.hdf. Please check it again MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021354.h18v04.061.2021355111839.hdf
# . Please check it again  . Please check it againCannot handle this MODIS file:
#
# Cannot handle this MODIS file:  Cannot handle this MODIS file: . Please check it again MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021227.h18v04.061.2021228104416.hdf  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021295.h18v04.061.2021299061341.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021171.h18v04.061.2021174154030.hdf . Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021110.h18v04.061.2021111094523.hdf. Please check it again
#
# Cannot handle this MODIS file:  Cannot handle this MODIS file: . Please check it again. Please check it again
#  Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021228.h18v04.061.2021229120413.hdf
#
#    MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021355.h18v04.061.2021356092351.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021111.h18v04.061.2021112102040.hdf. Please check it again Cannot handle this MODIS file:
#  Cannot handle this MODIS file: . Please check it again  . Please check it againCannot handle this MODIS file:
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021296.h18v04.061.2021299071012.hdf MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021172.h18v04.061.2021174155627.hdfCannot handle this MODIS file:
#   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021229.h18v04.061.2021230120156.hdf . Please check it again Cannot handle this MODIS file: . Please check it again
# . Please check it again
# Cannot handle this MODIS file:
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021356.h18v04.061.2021357093938.hdfCannot handle this MODIS file:   . Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021230.h18v04.061.2021231114540.hdf Cannot handle this MODIS file:
#  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021112.h18v04.061.2021113092108.hdfCannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021297.h18v04.061.2021299072612.hdf . Please check it again  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021173.h18v04.061.2021174193102.hdf
# . Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021357.h18v04.061.2021363202858.hdf
# Cannot handle this MODIS file: . Please check it again. Please check it againCannot handle this MODIS file: . Please check it again
# Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021298.h18v04.061.2021301151519.hdf
# . Please check it again
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021231.h18v04.061.2021232105204.hdf
# Cannot handle this MODIS file: Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021358.h18v04.061.2021363212005.hdf  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021299.h18v04.061.2021301153526.hdf. Please check it again
#  Cannot handle this MODIS file:  . Please check it again
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021113.h18v04.061.2021117071026.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021359.h18v04.061.2021364001818.hdf MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021174.h18v04.061.2021175092014.hdf  . Please check it againCannot handle this MODIS file: . Please check it again. Please check it again
# . Please check it again
#  Cannot handle this MODIS file:
#
#  Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021232.h18v04.061.2021233113407.hdf Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021360.h18v04.061.2022003213829.hdf . Please check it again   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021175.h18v04.061.2021176120527.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021300.h18v04.061.2021303195703.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021114.h18v04.061.2021117192327.hdf
# . Please check it again . Please check it againCannot handle this MODIS file:
#
#  . Please check it againCannot handle this MODIS file: . Please check it againCannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021233.h18v04.061.2021234124315.hdf
#
#   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021361.h18v04.061.2022003220128.hdfCannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021301.h18v04.061.2021303202107.hdf. Please check it again    . Please check it again
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021115.h18v04.061.2021118012957.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021176.h18v04.061.2021177120120.hdf. Please check it again
# Cannot handle this MODIS file:
#  Cannot handle this MODIS file: . Please check it again. Please check it againCannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021234.h18v04.061.2021235112952.hdf
#
#    Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021302.h18v04.061.2021303213208.hdf. Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021362.h18v04.061.2022003233710.hdf   . Please check it again
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021177.h18v04.061.2021178091201.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021116.h18v04.061.2021118053516.hdf. Please check it againCannot handle this MODIS file:
#  Cannot handle this MODIS file:
#  . Please check it again . Please check it againCannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021303.h18v04.061.2021304094900.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021235.h18v04.061.2021236155307.hdf
#
#    Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021363.h18v04.061.2022003234736.hdf. Please check it again. Please check it again   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021117.h18v04.061.2021119155136.hdf
#
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021178.h18v04.061.2021179090336.hdf. Please check it again Cannot handle this MODIS file:  Cannot handle this MODIS file:
#  . Please check it again Cannot handle this MODIS file: . Please check it again
# MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021236.h18v04.061.2021237094750.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021304.h18v04.061.2021306210823.hdf  Cannot handle this MODIS file:
#   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021364.h18v04.061.2022004012855.hdf. Please check it againCannot handle this MODIS file:  . Please check it again MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021118.h18v04.061.2021121004747.hdf
# . Please check it again MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021179.h18v04.061.2021182204412.hdf
#
# Cannot handle this MODIS file:  . Please check it again Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021237.h18v04.061.2021240184533.hdf
# . Please check it again   Cannot handle this MODIS file:
#  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021305.h18v04.061.2021306213908.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021365.h18v04.061.2022004014730.hdf. Please check it againCannot handle this MODIS file:   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021119.h18v04.061.2021121143304.hdf
#  . Please check it again. Please check it again
#  Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021180.h18v04.061.2021182223202.hdf
#  . Please check it again MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021238.h18v04.061.2021243084759.hdf
# . Please check it again . Please check it again
# Cannot handle this MODIS file:  Cannot handle this MODIS file:
# Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021120.h18v04.061.2021121211302.hdf  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021181.h18v04.061.2021183181244.hdf MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021239.h18v04.061.2021243144125.hdf. Please check it again  . Please check it again
# . Please check it again
# Cannot handle this MODIS file: Cannot handle this MODIS file:
#   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021121.h18v04.061.2021122115257.hdfCannot handle this MODIS file:   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021182.h18v04.061.2021188150649.hdfMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021240.h18v04.061.2021243150222.hdf. Please check it again
# . Please check it again. Please check it againCannot handle this MODIS file:
#
#  Cannot handle this MODIS file: Cannot handle this MODIS file: MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021122.h18v04.061.2021124184012.hdf   MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021183.h18v04.061.2021188161033.hdf. Please check it againMODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021241.h18v04.061.2021243160855.hdf
# . Please check it again. Please check it again
#
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021242.h18v04.061.2021243173831.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021243.h18v04.061.2021244104900.hdf . Please check it again
# Cannot handle this MODIS file:  MODIS/MOD_2021_MOD11A1/hdfs_files/MOD11A1.A2021244.h18v04.061.2021245103012.hdf . Please check it again
# Using 5.2694s to process product = MOD11A1.061

# %% [markdown]
# end of code for dataset

# %%
from torch.utils.data import Dataset
import numpy as np

# Define Dataset
class DatasetCustom(Dataset):
    def __init__(self, data_lst, data_nvdi, original_lst):
        # Data is an array of 2d images of size N x w x h
        self.data_lst = data_lst
        self.data_nvdi = data_nvdi
        self.original_lst = original_lst
        # assert self.data_lst.shape[0] == self.data_nvdi.shape[0], "NVDI and LST number of images is different. Indexing will break"

    def __len__(self):
        return self.data_lst.shape[0]

    def __getitem__(self, index):
        return self.data_lst[index,:,:], self.data_nvdi[int(index/2),:,:], self.original_lst[index,:,:]

# %%
class Conv_ReLU_Block(nn.Module):
    def __init__(self):
        super(Conv_ReLU_Block, self).__init__()
        self.conv = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        return self.relu(self.conv(x))

# %%
class VDSR(nn.Module):
    def __init__(self):
        super(VDSR, self).__init__()
        self.residual_layer = self.make_layer(Conv_ReLU_Block, 18)
        self.input = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=3, stride=1, padding=1, bias=False)
        self.output = nn.Conv2d(in_channels=64, out_channels=1, kernel_size=3, stride=1, padding=1, bias=False)
        self.relu = nn.ReLU(inplace=True)

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, sqrt(2. / n))

    def make_layer(self, block, num_of_layer):
        layers = []
        for _ in range(num_of_layer):
            layers.append(block())
        return nn.Sequential(*layers)

    def forward(self, x):
        residual = x
        out = self.relu(self.input(x))
        out = self.residual_layer(out)
        out = self.output(out)
        out = torch.add(out,residual)
        return out

num = 64

# %%
class DwSample(nn.Module):
    def __init__(self, inp, oup, stride, kernal_size = 3, groups=1, BN = False):
        super(DwSample, self).__init__()
        if BN == True:
            self.conv_dw = nn.Sequential(
                nn.Conv2d(inp, oup, kernal_size, stride, int((kernal_size - 1) / 2), groups=groups),
                nn.BatchNorm2d(oup),
                nn.PReLU(),
            )
        else:
            self.conv_dw = nn.Sequential(
                nn.Conv2d(inp, oup, kernal_size, stride, int((kernal_size-1)/2), groups=groups),
                nn.PReLU(),
            )

    def forward(self, x):
        residual = x
        out = self.conv_dw(x)
        return torch.add(out, residual)

# %%
class BasicBlock(nn.Module):
    def __init__(self, inp, oup, stride, kernal_size=3, groups=1, BN = False):
        super(BasicBlock, self).__init__()
        if BN == True:
            self.conv_dw = nn.Sequential(
                nn.Conv2d(inp, oup, kernal_size, stride, int((kernal_size - 1) / 2), groups=groups),
                nn.BatchNorm2d(oup),
                nn.PReLU(),
                nn.Conv2d(oup, inp, kernal_size, stride, int((kernal_size - 1) / 2), groups=groups),
            )
        else:
            self.conv_dw = nn.Sequential(
                nn.Conv2d(inp, oup, kernal_size, stride, int((kernal_size - 1) / 2), groups=groups),
                nn.PReLU(),
                nn.Conv2d(oup, inp, kernal_size, stride, int((kernal_size - 1) / 2), groups=groups),
            )
    def forward(self, x):
        residual = x
        return torch.add(self.conv_dw(x), residual)

# %%
class UpSample(nn.Module):
    def __init__(self, f, upscale_factor):
        super(UpSample, self).__init__()

        self.relu = nn.PReLU()
        self.conv = nn.Conv2d(f, f * (upscale_factor ** 2), (3, 3), (1, 1), (1, 1))
        self.pixel_shuffle = nn.PixelShuffle(upscale_factor)

    def forward(self, x):
        x = self.relu(self.conv(x))
        x = self.pixel_shuffle(x)
        return x

# %%
class DMCN_prelu(nn.Module):
    def __init__(self, BN=True, width = 64):
        super(DMCN_prelu, self).__init__()
        self.input1 = nn.Conv2d(in_channels=1, out_channels=width, kernel_size=3, stride=1, padding=1, bias=False)
        self.input2 = nn.Conv2d(in_channels=width, out_channels=width, kernel_size=3, stride=1, padding=1, bias=False)
        self.BN1 = nn.BatchNorm2d(width)
        self.input3 = nn.Conv2d(in_channels=width, out_channels=width, kernel_size=3, stride=1, padding=1, bias=False)
        self.BN2 = nn.BatchNorm2d(width)
        self.input4 = nn.Conv2d(in_channels=width, out_channels=width, kernel_size=3, stride=1, padding=1, bias=False)
        self.BN3 = nn.BatchNorm2d(width)
        self.input5 = nn.Conv2d(in_channels=width, out_channels=width, kernel_size=3, stride=1, padding=1, bias=False)
        self.BN4 = nn.BatchNorm2d(width)
        self.down_sample1 = nn.Conv2d(in_channels=width, out_channels=width, kernel_size=3, stride=2, padding=1, bias=False)
        self.Conv_DW_layers1 = self.make_layer(DwSample, 5, BN, width)

        self.down_sample2 = nn.Conv2d(in_channels=width, out_channels=width, kernel_size=3, stride=2, padding=1, bias=False)
        self.Conv_DW_layers2 = self.make_layer(DwSample, 2, BN, width)

        self.up_sample1 = UpSample(width,2)

        self.choose1 = nn.Conv2d(in_channels=width*2, out_channels=width, kernel_size=1, stride=1, padding=0, bias=False)
        self.resudial_layers1 = self.make_layer(BasicBlock, 2, BN, width)

        self.up_sample2 = UpSample(width,2)

        self.choose2 = nn.Conv2d(in_channels=width*2, out_channels=width, kernel_size=1, stride=1, padding=0, bias=False)
        self.resudial_layers2 = self.make_layer(BasicBlock, 5, BN, width)

        self.output = nn.Conv2d(in_channels=width, out_channels=1, kernel_size=3, stride=1, padding=1, bias=False)

        self.relu = nn.PReLU()

# %%
 def make_layer(self, block, num_of_layer, BN, width):
        layers = []
        for _ in range(num_of_layer):
            layers.append(block(width, width, 1, 3, 1, BN))
        return nn.Sequential(*layers)

# %%
    def forward(self, x):
        residual = x
        s1 = self.relu(self.input1(x))
        s1 = self.input2(s1)
        s1 = self.relu(self.BN1(s1))
        s1 = self.input3(s1)
        s1 = self.relu(self.BN2(s1))
        s1 = self.input4(s1)
        s1 = self.relu(self.BN3(s1))
        s1 = self.input5(s1)
        s1 = self.relu(self.BN4(s1))
        out = self.down_sample1(s1)
        s2 = self.Conv_DW_layers1(out)

        out = self.down_sample2(s2)
        out = self.Conv_DW_layers2(out)

        out = self.up_sample1(out)
        out = torch.cat((s2, out), 1)
        out = self.choose1(out)
        out = self.resudial_layers1(out)

        out = self.up_sample2(out)
        out = torch.cat((s1, out), 1)
        out = self.choose2(out)
        out = self.resudial_layers2(out)

        out = self.output(out)
        out = torch.add(out, residual)
        return out


""" Parts of the U-Net model """
# Out:
# ' Parts of the U-Net model '

# %%
class DoubleConv(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super(DoubleConv, self).__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)

# %%
class DoubleConv_Down(nn.Module):
    """(convolution => [BN] => ReLU) * 2"""

    def __init__(self, in_channels, out_channels, mid_channels=None):
        super(DoubleConv_Down, self).__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
        )

    def forward(self, x):
        return self.double_conv(x)

# %%
class Down(nn.Module):
    """Downscaling with maxpool then double conv"""

    def __init__(self, in_channels, out_channels, res_down=False):
        super(Down, self).__init__()
        self.res_down = res_down
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            DoubleConv(in_channels, out_channels)
        )
        if self.res_down:
            self.in_conv = nn.Conv2d(in_channels, in_channels, kernel_size=2, stride=2)
            self.mid_conv = DoubleConv(in_channels, in_channels)
            self.out_conv = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(inplace=True)
            )

    def forward(self, x):
        if self.res_down:
            return self.out_conv(self.mid_conv((self.in_conv(x))) + self.in_conv(x))

        else:
            return self.maxpool_conv(x)

# %%
class Up(nn.Module):
    """Upscaling then double conv"""

    def __init__(self, in_channels, out_channels, bilinear=True):
        super(Up, self).__init__()

        # if bilinear, use the normal convolutions to reduce the number of channels
        if bilinear:
            self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
            self.conv = DoubleConv(in_channels, out_channels, in_channels // 2)
        else:
            self.up = nn.ConvTranspose2d(in_channels, in_channels // 2, kernel_size=2, stride=2)
            self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        # input is CHW
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]

        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2],mode='reflect')
        # if you have padding issues, see
        # https://github.com/HaiyongJiang/U-Net-Pytorch-Unstructured-Buggy/commit/0e854509c2cea854e247a9c615f175f76fbb2e3a
        # https://github.com/xiaopeng-liao/Pytorch-UNet/commit/8ebac70e633bac59fc22bb5195e513d5832fb3bd
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)

# %%
class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)
        # self.conv = nn.Sequential(
        #     nn.Conv2d(in_channels, out_channels, kernel_size=1),
        #     nn.Sigmoid())

    def forward(self, x):
        return self.conv(x)

# %%
class ResnetBlock(nn.Module):
    """Define a Resnet block"""

    def __init__(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        """Initialize the Resnet block
        A resnet block is a conv block with skip connections
        We construct a conv block with build_conv_block function,
        and implement skip connections in <forward> function.
        Original Resnet paper: https://arxiv.org/pdf/1512.03385.pdf
        """
        super(ResnetBlock, self).__init__()
        self.conv_block = self.build_conv_block(dim, padding_type, norm_layer, use_dropout, use_bias)

    def build_conv_block(self, dim, padding_type, norm_layer, use_dropout, use_bias):
        """Construct a convolutional block.
        Parameters:
            dim (int)           -- the number of channels in the conv layer.
            padding_type (str)  -- the name of padding layer: reflect | replicate | zero
            norm_layer          -- normalization layer
            use_dropout (bool)  -- if use dropout layers.
            use_bias (bool)     -- if the conv layer uses bias or not
        Returns a conv block (with a conv layer, a normalization layer, and a non-linearity layer (ReLU))
        """
        conv_block = []
        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)

        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias), norm_layer(dim), nn.ReLU(True)]
        if use_dropout:
            conv_block += [nn.Dropout(0.5)]

        p = 0
        if padding_type == 'reflect':
            conv_block += [nn.ReflectionPad2d(1)]
        elif padding_type == 'replicate':
            conv_block += [nn.ReplicationPad2d(1)]
        elif padding_type == 'zero':
            p = 1
        else:
            raise NotImplementedError('padding [%s] is not implemented' % padding_type)
        conv_block += [nn.Conv2d(dim, dim, kernel_size=3, padding=p, bias=use_bias), norm_layer(dim)]

        return nn.Sequential(*conv_block)

    def forward(self, x):
        """Forward function (with skip connections)"""
        out = x + self.conv_block(x)  # add skip connections
        return out

# %%
class MRUNet(nn.Module):
    def __init__(self, n_channels=1, n_classes=1, res_down=False, n_resblocks=1, padding_type="reflect", norm_layer=nn.BatchNorm2d, use_dropout=False, use_bias=True, bilinear=False):
        super(MRUNet, self).__init__()
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.bilinear = bilinear

        self.inc = DoubleConv(n_channels, 64)

        ### Encoder
        self.down1 = Down(64, 128, res_down=res_down)
        self.down2 = Down(128, 256, res_down=res_down)
        self.down3 = Down(256, 512, res_down=res_down)
        factor = 2 if bilinear else 1
        self.down4 = Down(512, 1024 // factor, res_down=res_down)

        ### Residual blocks
        resblocks = []
        for i in range(n_resblocks):
            resblocks += [ResnetBlock(1024 // factor, padding_type, norm_layer, use_dropout, use_bias)]
        self.resblocks = nn.Sequential(*resblocks)

        ### Decoder
        self.up1 = Up(1024, 512 // factor, bilinear)
        self.up2 = Up(512, 256 // factor, bilinear)
        self.up3 = Up(256, 128 // factor, bilinear)
        self.up4 = Up(128, 64, bilinear)
        self.outc = OutConv(64, n_classes)
        self.up = nn.ConvTranspose2d(64, 64, kernel_size=2, stride=2)
        self.up_dc = DoubleConv(64, 64)
        self.drop = nn.Dropout(p=0.3)

    def forward(self, x):
        x1 = self.inc(x) #256
        x2 = self.down1(x1) #512
        x3 = self.down2(x2) #1024
        x4 = self.down3(x3) #2048
        x5 = self.down4(x4) #4096

        x5 = self.resblocks(x5)

        xp1 = self.up1(x5, x4) #2048
        xp2 = self.up2(xp1, x3) #1024
        xp3 = self.up3(xp2, x2) #512
        xp4 = self.up4(xp3, x1) #256
        # x = self.up(x)
        # x = self.up_dc(x)
        logits = self.outc(xp4)+x
        return logits
